# %% [markdown]
# <a href="https://colab.research.google.com/github/Cinderella23/COMP_122/blob/main/Investigating_a_dataset_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Harry Potter and the Data Set
#     Comp 122 - Spring 2023 FINAL PROJECT
#     By: Ella R

# %% [markdown]
# ## Table of Contents
# <ul>
# <li><a href="#intro">I. Introduction</a></li>
# <li><a href="#wrangling">II. Data Wrangling</a></li>
# <li><a href="#eda">III. Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">IV. Conclusions</a></li>
# </ul>

# %% [markdown]
# ----
# <a id='intro'></a>
# ## I. INTRODUCTION
#
# In this project I will analyze the "Titles" dataset which contains information on the Harry Potter books and series. Harry Potter is a popular fantasy series created by British author J.K. Rowling which has been translated into multiple languages for worldwide audiences. The series primarily consists of seven novels, which were later adapted into eight films. The story follows the life of a young wizard named Harry Potter and his friends Hermione Granger and Ron Weasley as they attend Hogwarts School of Witchcraft and Wizardry. My data set contains information on the content of the books published, languages, and library filing procedures.
# <br> <br>
# ![](https://www.scholastic.com/content/dam/scholastic/educators/book-lists/Harry-Potter-Book-List_BL_16-9.jpg.corpimagerendition.xxl.1400.788.png)
# <br>
#
# ##I will try to find answers to the following questions:<br>
#
# 1) How many different languages were the books translated to and published in? <br>
# 2) How many books were published in print vs. online resources?

# %%
#Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading dataset into Pandas DataFrame

link= "/content/titles.csv" 
df= pd.read_csv(link)

# %% [markdown]
# <a id='eda'></a>
# ## Exploring the Dataset

# %%
#First 10 Rows
df.head(10)
# Out:
#                                                Title  \
# 0  'Garri Potter' v t︠s︡erkvi : mezhdu anafemoĭ i...
# 1  'Harry Potter and the Transmedia Wizarding Wor...
# 2  'Harry Potter and the order of the phoenix' .....
# 3  'Harry Potter' in der Schule : didaktische Ann...
# 4      'Magiczna' wyobraźnia czy realistyczna magia?
# 5  'Mudbloods' und 'Half-Breeds' : Rassismus und ...
# 6                     101 amazing Harry Potter facts
# 7  101 amazing facts about J.K. Rowling and Harry...
# 8                101 more amazing Harry Potter facts
# 9      50 Amazing Cocktails Inspired by Harry Potter
#
#                                         Other titles  BL record ID  \
# 0                                                NaN      12985093
# 1                                                NaN      19560516
# 2                                                NaN      14558822
# 3                                                NaN      12459662
# ...

# %%
#Last 10 Rows
df.tail(10)
# Out:
#                                  Title  \
# 870  Фантазия и правда 'Кода да Винчи'
# 871           هاري بوتر و حجر الفيلسوف
# 872     ཧ་རུའེ་ཕོད་ཐར་དང་གསང་བའི་ཁང་པ།
# 873           ཧ་རུའེ་ཕོད་ཐར་དང་ཚེ་རྡོ།
# 874                             哈利. 波特
# 875                              消失的密室
# 876                              火盃的考驗
# 877                             神秘的魔法石
# 878                            阿茲卡班的逃犯
# 879                             鳳凰會的密令
#
#                                           Other titles  BL record ID  \
# 870               Fantazii︠a︡ i pravda 'Koda da Vinchi      14644440
# 871  Harry Potter and the philosopher's stone. Arab...      18414446
# 872  Ha-ruʾe Phod-thar dang gsang baʾi khang pa ; H...      18306676
# 873  Ha-ruʾe Phod-thar dang tshe rdo ; Harry Potter...      18306670
# 874  Feng huang hui de mi ling ; Ha li . bo te ; Ha...      18113703
# 875  Feng huang hui de mi ling ; Ha li . bo te ; Ha...      18113703
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 880 entries, 0 to 879
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Title                       880 non-null    object
#  1   Other titles                294 non-null    object
#  2   BL record ID                880 non-null    int64
#  3   Type of resource            880 non-null    object
#  4   Content type                880 non-null    object
#  5   Material type               846 non-null    object
#  6   BNB number                  542 non-null    object
#  7   ISBN                        834 non-null    object
#  8   ISSN                        6 non-null      object
#  9   Name                        652 non-null    object
#  10  Dates associated with name  98 non-null     object
#  11  Type of name                652 non-null    object
#  12  Role                        299 non-null    object
# ...

# %%
df.describe()
# Out:
#        BL record ID
# count  8.800000e+02
# mean   1.617296e+07
# std    3.330075e+06
# min    6.608117e+06
# 25%    1.381455e+07
# 50%    1.695463e+07
# 75%    1.882894e+07
# max    2.030500e+07

# %%
df.nunique()
# Out:
# Title                         634
# Other titles                  283
# BL record ID                  681
# Type of resource                4
# Content type                    8
# Material type                  14
# BNB number                    478
# ISBN                          646
# ISSN                            4
# Name                          180
# Dates associated with name     35
# Type of name                    3
# Role                            3
# All names                     278
# Series title                   75
# Number within series           36
# Country of publication         29
# Place of publication          135
# Publisher                     232
# Date of publication            31
# Edition                        64
# Physical description          470
# Dewey classification           77
# BL shelfmark                  358
# Topics                        319
# Genre                          45
# Languages                      30
# ...

# %%
df.dtypes
# Out:
# Title                         object
# Other titles                  object
# BL record ID                   int64
# Type of resource              object
# Content type                  object
# Material type                 object
# BNB number                    object
# ISBN                          object
# ISSN                          object
# Name                          object
# Dates associated with name    object
# Type of name                  object
# Role                          object
# All names                     object
# Series title                  object
# Number within series          object
# Country of publication        object
# Place of publication          object
# Publisher                     object
# Date of publication           object
# Edition                       object
# Physical description          object
# Dewey classification          object
# BL shelfmark                  object
# Topics                        object
# ...

# %%
df["Genre"].value_counts()
# Out:
# Children's fiction ; Fantasy                                                    123
# Children's literature                                                            64
# Children's fiction                                                               52
# Fantasy ; Fiction                                                                41
# Children's fiction ; Fiction                                                     25
# Criticsm and interpretation                                                      17
# Excerpt                                                                          10
# Biography                                                                         8
# Children's literature ; Pictorial work                                            8
# Excerpt ; Piano score                                                             8
# Pictorial work                                                                    8
# ...

# %%
df["Title"].value_counts()
# Out:
# Harry Potter and the philosopher's stone                                                                     28
# Harry Potter and the chamber of secrets                                                                      26
# Harry Potter and the prisoner of Azkaban                                                                     26
# Harry Potter and the goblet of fire                                                                          24
# Harry Potter and the Order of the Phoenix                                                                    20
#                                                                                                              ..
# Harry Potter and the cursed child : parts I & II                                                              1
# Harry Potter and the cursed child : parts one and two                                                         1
# ...

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %%
df.drop_duplicates()
# Out:
#                                                  Title  \
# 0    'Garri Potter' v t︠s︡erkvi : mezhdu anafemoĭ i...
# 1    'Harry Potter and the Transmedia Wizarding Wor...
# 2    'Harry Potter and the order of the phoenix' .....
# 3    'Harry Potter' in der Schule : didaktische Ann...
# 4        'Magiczna' wyobraźnia czy realistyczna magia?
# ..                                                 ...
# 875                                              消失的密室
# 876                                              火盃的考驗
# 877                                             神秘的魔法石
# 878                                            阿茲卡班的逃犯
# 879                                             鳳凰會的密令
#
#                                           Other titles  BL record ID  \
# 0                                                  NaN      12985093
# 1                                                  NaN      19560516
# 2                                                  NaN      14558822
# ...

# %%
cleaned_data= df.drop(['ISSN', 'BNB number','Dewey classification'], axis=1)

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis

# %% [markdown]
# ### Research Question 1: How many different languages were the books translated to and published in?

# %%
#Count how many languages appear and isolate the column

counting_languages=cleaned_data.groupby("Languages").count()

sorting=counting_languages.drop(columns=['Other titles', "BL record ID",	"Type of resource",	"Content type",	"Material type", "ISBN",	"Name",	"Dates associated with name",	"Type of name",	
                    "Role",	"All names",	"Series title",	"Number within series", 	"Place of publication",	"Publisher",	"Date of publication",	"Edition",	"Physical description",
                    "BL shelfmark",	"Topics","Country of publication", "Genre","Notes"])
sorting
# Out:
#                           Title
# Languages
# Afrikaans                     2
# Arabic                        3
# Burmese                       2
# Catalan                       8
# Chinese                      19
# Dutch                        10
# English                     669
# English ; German              7
# English ; Italian             1
# English ; Latin               2
# English ; Swedish             1
# French                       11
# German                       22
# Greek, Ancient (to 1453)      1
# Hawaiian                      2
# Hungarian                     1
# Indonesian                    2
# Irish                         4
# Italian                       5
# Latin                         4
# Maori                         3
# Polish                        5
# Russian                       3
# Scots                         2
# Spanish                       5
# Swedish                       1
# Thai                          2
# Tibetan                       6
# ...

# %%
#Create pie chart to illustate disturibution of languages

piechart = pd.DataFrame({'Language': ['Afrikaans', 'Arabic', 'Burmese',
                                   'Catalan', 'Chinese', 'Dutch', 
                                   'English', 'English ; German', 'English ; Italian', 'English ; Latin',
                                   'English ; Swedish', 'French', 'German',
                                   'Greek, Ancient', 'Hawaiian','Hungarian', 'Indonesian', 'Irish','Italian', 'Latin','Maori', 
                                   'Polish', 'Russian', 'Scots', 'Spanish',
                                   'Swedish', 'Thai', 'Tibetan',
                                   'Ukrainian', 'Welsh'],
                                   
                          



                          'copies_of_books': [2, 3, 2, 8, 19, 
                                                  10, 669, 7, 1, 2, 
                                                  1, 11, 22, 1, 2, 1,2,4,5,4,3, 5, 3, 2, 5, 
                                                  1, 2, 6, 15, 6 ]})
  
# Plotting the pie chart for above dataframe
piechart.groupby(['Language']).sum().plot(kind='pie', y='copies_of_books')
# Out:
# <Axes: ylabel='copies_of_books'>

# %%
#Counting the 

def adding_total():
  count=0 
  for i in df['Languages'].value_counts():
    count=count+1
  print("There are",count, "total languages the books were translated into.")
adding_total()
# Out:
# There are 30 total languages the books were translated into.

# %% [markdown]
# ### Research Question 2: How many books were published in print vs. online resources?

# %%
#Comparing digital books to physical books buy adding how many times relevant keywords appear in column

def books_format():
  physical_books = df['Physical description'].str.contains('volume').sum() + df['Physical description'].str.contains('pages').sum()
  digital_books = df['Physical description'].str.contains('online').sum()

  print(physical_books, "are physical books and" , digital_books, "are digital books.")
books_format()
# Out:
# 780 are physical books and 91 are digital books.

# %% [markdown]
# Do any of these books contain Illustrations as well?

# %%
def books_illustrated():
  illustrations = df['Physical description'].str.contains('illustrations').sum()
  if illustrations > 1:
    return True, illustrations 
books_illustrated()
# Out:
# (True, 356)

# %%
#plotting bar chart

import matplotlib.pyplot as plt
   
country = ['Physical Books', 'Digtal Books','Boooks with illustrations']
gdp_per_capita = [780, 91,356]

colors = ['purple','teal', 'red']
plt.bar(country, gdp_per_capita, color=colors)
plt.title('Physical Book Copies Vs Digital Book Copies')
plt.xlabel('Book Format')
plt.ylabel('Copies Available')
plt.show()

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions

# %% [markdown]
# **How many different languages were the books translated into and published in?**
#
# Based on the analysis of my data, the books are translated into a vast array of languages, up to 30 in total. Moreover, English appears to be the dominant language of publication, with a staggering 81% of all books being written in this language. Interestingly, only a tiny fraction of languages, around 0.013%, are considered derivatives of English, including German, Italian, Latin, and Swedish in addition to the other worldwide languages.
#
# **How many books were published in print vs. online resources?**
#
# There are 210 books that mention "volume" in their physical description, and 570 books that mention "pages" in their description. This suggests that these books are physical publications. Furthermore, 91 of these books use the keyword "digital," suggesting that they are available as online resources. In addition to this 356 of these books contain illustrated content. Out of all the books, 64% are in physical form, whereas only a meager 0.07% are available in digital format. Additionally, 29% of the physical books have illustrations.

# %% [markdown]
# <a id='conclusions'></a>
# ## Limitations
#
# I want to mention that there could be some limitations to this project. Firstly, some columns were removed from the dataset because they didn't contain any relevant information that could impact the calculation of totals. Also, the percentages in the data analysis were rounded based on my specifications. Additionally, it's important to note that this dataset may not be up to date, so it may not include information on newly published Harry Potter books or editions. As a result, it's possible that not every single book in the Harry Potter series is included in the dataset.
